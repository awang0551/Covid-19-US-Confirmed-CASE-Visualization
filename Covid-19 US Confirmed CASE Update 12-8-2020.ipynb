# %%
import os

os.chdir(r'C:\Work\Data Science\14 Project\1')

# %%
os.getcwd()
# Out:
# 'C:\\Work\\Data Science\\14 Project\\1'

# %%
import numpy as py
import pandas as pd
import plotly as plt
from numpy.random import randn
import plotly.express as px
import plotly.graph_objs as go
from plotly.subplots import make_subplots
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df_line=pd.read_csv('COVID19_line_list_data.csv')

# %%
df=pd.read_csv('covid_19_data.csv')

# %%
df=pd.DataFrame(df)

# %%
df
# Out:
#            SNo ObservationDate     Province/State  Country/Region  \
# 0            1      01/22/2020              Anhui  Mainland China
# 1            2      01/22/2020            Beijing  Mainland China
# 2            3      01/22/2020          Chongqing  Mainland China
# 3            4      01/22/2020             Fujian  Mainland China
# 4            5      01/22/2020              Gansu  Mainland China
# ...        ...             ...                ...             ...
# 172475  172476      12/06/2020  Zaporizhia Oblast         Ukraine
# 172476  172477      12/06/2020            Zeeland     Netherlands
# 172477  172478      12/06/2020           Zhejiang  Mainland China
# 172478  172479      12/06/2020    Zhytomyr Oblast         Ukraine
# 172479  172480      12/06/2020       Zuid-Holland     Netherlands
#
#                 Last Update  Confirmed  Deaths  Recovered
# 0           1/22/2020 17:00        1.0     0.0        0.0
# ...

# %%
df.groupby('Country/Region').count().loc['US']
# Out:
# SNo                16648
# ObservationDate    16648
# Province/State     16648
# Last Update        16648
# Confirmed          16648
# Deaths             16648
# Recovered          16648
# Name: US, dtype: int64

# %%
df.groupby('Country/Region').count().loc['Mainland China'].describe()
# Out:
# count       7.0
# mean     9918.0
# std         0.0
# min      9918.0
# 25%      9918.0
# 50%      9918.0
# 75%      9918.0
# max      9918.0
# Name: Mainland China, dtype: float64

# %%
df['Country/Region'='US']
# Out:
#   File "<ipython-input-43-0b035eb1a552>", line 1
#     df['Country/Region'='US']
#                        ^
# SyntaxError: invalid syntax

# %%
df1 = pd.DataFrame(randn(5,4)*50,['a','b','c','d','e'],['1','2','3','4'])

# %%
df1
# Out:
#            1          2          3          4
# a  66.513010  21.987209 -40.732351  22.337563
# b  41.387679  53.707008  49.613481 -22.291697
# c  -7.005260  47.026349  89.734111   9.860105
# d  62.096331  61.504222 -51.729266  30.848029
# e -16.368601 -13.600910 -53.438155 -66.149085

# %%
randn(1)
# Out:
# array([0.72801388])

# %%
df['Country/Region']
# Out:
# 0         Mainland China
# 1         Mainland China
# 2         Mainland China
# 3         Mainland China
# 4         Mainland China
#                ...
# 172475           Ukraine
# 172476       Netherlands
# 172477    Mainland China
# 172478           Ukraine
# 172479       Netherlands
# Name: Country/Region, Length: 172480, dtype: object

# %%
df['Last Update']
# Out:
# 0             1/22/2020 17:00
# 1             1/22/2020 17:00
# 2             1/22/2020 17:00
# 3             1/22/2020 17:00
# 4             1/22/2020 17:00
#                  ...
# 172475    2020-12-07 05:26:14
# 172476    2020-12-07 05:26:14
# 172477    2020-12-07 05:26:14
# 172478    2020-12-07 05:26:14
# 172479    2020-12-07 05:26:14
# Name: Last Update, Length: 172480, dtype: object

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['total']= df['Deaths']+df['Recovered']

# %%
df
# Out:
#            SNo ObservationDate     Province/State  Country/Region  \
# 0            1      01/22/2020              Anhui  Mainland China
# 1            2      01/22/2020            Beijing  Mainland China
# 2            3      01/22/2020          Chongqing  Mainland China
# 3            4      01/22/2020             Fujian  Mainland China
# 4            5      01/22/2020              Gansu  Mainland China
# ...        ...             ...                ...             ...
# 172475  172476      12/06/2020  Zaporizhia Oblast         Ukraine
# 172476  172477      12/06/2020            Zeeland     Netherlands
# 172477  172478      12/06/2020           Zhejiang  Mainland China
# 172478  172479      12/06/2020    Zhytomyr Oblast         Ukraine
# 172479  172480      12/06/2020       Zuid-Holland     Netherlands
#
#                 Last Update  Confirmed  Deaths  Recovered    total
# 0           1/22/2020 17:00        1.0     0.0        0.0      0.0
# ...

# %%
df.drop('total',axis=1,inplace=True)

# %%
df['Country/Region'].nunique()
# Out:
# 226

# %%
df['Country/Region'].value_counts()
# Out:
# US                     16648
# Russia                 15809
# Mainland China          9918
# Japan                   9533
# India                   6744
#                        ...
# North Ireland              1
# East Timor                 1
# Republic of Ireland        1
# Cape Verde                 1
# St. Martin                 1
# Name: Country/Region, Length: 226, dtype: int64

# %%
df.sort_values('Confirmed')
# Out:
#            SNo        Date                         State   Country  \
# 146716  146717  11/02/2020                       Unknown  Colombia
# 105388  105389  09/08/2020  Diamond Princess cruise ship    Canada
# 122780  122781  10/01/2020                     Recovered        US
# 159100  159101  11/19/2020  Diamond Princess cruise ship    Canada
# 129320  129321  10/10/2020                   Lakshadweep     India
# ...        ...         ...                           ...       ...
# 168734  168735  12/02/2020                           NaN    France
# 169494  169495  12/03/2020                           NaN    France
# 170254  170255  12/04/2020                           NaN    France
# 171014  171015  12/05/2020                           NaN    France
# 171774  171775  12/06/2020                           NaN    France
#
#                 Last Update  Confirmed   Deaths  Recovered
# 146716  2020-11-03 06:00:16  -302844.0      0.0        0.0
# ...

# %%
df.columns
# Out:
# Index(['SNo', 'ObservationDate', 'Province/State', 'Country/Region',
#        'Last Update', 'Confirmed', 'Deaths', 'Recovered'],
#       dtype='object')

# %%
df=df.rename(columns={'Country/Region' : 'Country'})

# %%
df=df.rename(columns={'ObservationDate':'Date'})

# %%
df=df.rename(columns={'Province/State':'State'})

# %%
df_us=df[df['Country'] == 'US']

# %%
df_us.head(10)
# Out:
#      SNo        Date       State Country      Last Update  Confirmed  Deaths  \
# 31    32  01/22/2020  Washington      US  1/22/2020 17:00        1.0     0.0
# 69    70  01/23/2020  Washington      US    1/23/20 17:00        1.0     0.0
# 117  118  01/24/2020  Washington      US    1/24/20 17:00        1.0     0.0
# 118  119  01/24/2020     Chicago      US    1/24/20 17:00        1.0     0.0
# 158  159  01/25/2020  Washington      US    1/25/20 17:00        1.0     0.0
# 159  160  01/25/2020    Illinois      US    1/25/20 17:00        1.0     0.0
# 202  203  01/26/2020  Washington      US    1/26/20 16:00        1.0     0.0
# 203  204  01/26/2020    Illinois      US    1/26/20 16:00        1.0     0.0
# 204  205  01/26/2020  California      US    1/26/20 16:00        2.0     0.0
# 205  206  01/26/2020     Arizona      US    1/26/20 16:00        1.0     0.0
#
#      Recovered
# 31         0.0
# 69         0.0
# 117        0.0
# 118        0.0
# 158        0.0
# 159        0.0
# ...

# %%
df_us_states = df_us.groupby(['State','Date']).sum().reset_index().sort_values('Date',ascending=False)

# %%
df_us_states.

# %%
df_us_states.head(50)
# Out:
#                               State        Date     SNo  Confirmed   Deaths  \
# 12719                     Recovered  12/06/2020  172316        0.0      0.0
# 1106                       Arkansas  12/06/2020  171925   170924.0   2660.0
# 834                         Arizona  12/06/2020  171924   364276.0   6950.0
# 3167                        Florida  12/06/2020  172034  1058074.0  19177.0
# 8280                       Missouri  12/06/2020  172208   329420.0   4284.0
# 6629                          Maine  12/06/2020  172183    13348.0    227.0
# 1759                       Colorado  12/06/2020  172003   260581.0   3356.0
# 2874           District of Columbia  12/06/2020  172018    23136.0    697.0
# 3735                 Grand Princess  12/06/2020  172055      103.0      3.0
# 10479                North Carolina  12/06/2020  172251   394990.0   5543.0
# 7188                  Massachusetts  12/06/2020  172191   256844.0  11004.0
# ...

# %%
data = dict(type = 'choropleth',
            locations = df_us_states['State'],
            locationmode = 'USA-states',
            colorscale = 'Reds',
            text = df_us_states['State'],
            z = df_us_states['Confirmed'])

# %%
layout = dict(geo = {'scope':'usa'})

# %%
choromap = go.Figure(data = [data],layout = layout)

# %%
iplot(choromap)
# Out:
# <div>
#
#
#             <div id="68f161c4-d44c-4f53-80ed-3f48b145c804" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("68f161c4-d44c-4f53-80ed-3f48b145c804")) {
#                     Plotly.newPlot(
#                         '68f161c4-d44c-4f53-80ed-3f48b145c804',
# ...
